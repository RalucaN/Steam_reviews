# %% [markdown]
# # Data Exploration
# This notebook continues the exploration started in part B (data processing) by conducting univariate, bivariate and multivariate analysis. I also plan to gather new data regarding steam users by making a new api request.

# %%
# Importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data
gameid=892970
data= pd.read_csv("Data/"+str(gameid)+"_clean.csv")
data.head()
# Out:
#    recommendationid                                             review  \
# 0         140348666  I played this for 99 minutes EXACTLY. and I HA...
# 1         140347990  this game is amazing, and even better with the...
# 2         140347860      GAME IS horrible gave me fucking cancer sound
# 3         140345029  The only bad thing about this game is the amou...
# 4         140343169                                               nice
#
#    timestamp_created  timestamp_updated  voted_up  votes_up  votes_funny  \
# 0         1687201179         1687201179     False         0            0
# 1         1687200393         1687200393      True         0            0
# 2         1687200233         1687200233     False         1            0
# 3         1687196855         1687196855      True         0            0
# 4         1687194571         1687194571      True         0            0
#
#    weighted_vote_score  comment_count  steam_purchase  ...  last_played  \
# 0              0.00000              0           False  ...   1614510611
# 1              0.00000              0            True  ...   1687202643
# 2              0.52381              1            True  ...   1687200165
# 3              0.00000              0            True  ...   1687196885
# 4              0.00000              0            True  ...   1687201992
#
#    timestamp_created_utc  timestamp_updated_utc      last_played_utc  \
# 0    2023-06-19 18:59:39    2023-06-19 18:59:39  2021-02-28 11:10:11
# 1    2023-06-19 18:46:33    2023-06-19 18:46:33  2023-06-19 19:24:03
# 2    2023-06-19 18:43:53    2023-06-19 18:43:53  2023-06-19 18:42:45
# 3    2023-06-19 17:47:35    2023-06-19 17:47:35  2023-06-19 17:48:05
# 4    2023-06-19 17:09:31    2023-06-19 17:09:31  2023-06-19 19:13:12
#
#    playtime_forever_hour  playtime_last_two_weeks_hour  \
# 0                    1.6                           0.0
# 1                   29.8                          29.8
# 2                   19.4                           3.0
# 3                  384.8                           0.0
# 4                   49.7                           2.0
#
#    playtime_at_review_hour  timestamp_created_utc_ym timestamp_updated_utc_ym  \
# 0                      1.6                   2023-06                  2023-06
# 1                     29.2                   2023-06                  2023-06
# 2                     19.4                   2023-06                  2023-06
# 3                    384.8                   2023-06                  2023-06
# 4                     47.6                   2023-06                  2023-06
#
#   last_played_utc_ym
# 0            2021-02
# 1            2023-06
# 2            2023-06
# 3            2023-06
# 4            2023-06
#
# [5 rows x 27 columns]

# %% [markdown]
# ---
# ### Plot the frequency of (new / created) reviews across time

# %%
y=data['timestamp_created_utc_ym'].value_counts(sort=False)
y.index=pd.to_datetime(y.index)

fig, ax = plt.subplots()
ax.plot_date(y.index,y.values, fmt=",-")
ax.set(title = "Frequency of new reviews across time",
       xlabel = "Year-Month",
       ylabel = "Counts of new reviews")
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# > There seems to be a high number of reviews in the first 3 months since the game was available for review. Let's look at total reviews created before and after April 2021

# %%
# total number of reviews created before or on April 2021 
y.loc[y.index <= '2021-04'].sum()
# Out:
# 145017

# %%
# Total number of reviews created after April 2021
y.loc[y.index > '2021-04'].sum()
# Out:
# 98779

# %%
y.tail(3)
# Out:
# 2021-04    14509
# 2021-03    49923
# 2021-02    80585
# Name: timestamp_created_utc_ym, dtype: int64

# %% [markdown]
# > In the first 3 months of availability, 145,017 new reviews were added by users:
#
#                 - Feb 2021 - 80,585 reviews
#                 - March 2021 - 49,923 reviews
#                 - April 2021 - 14,509 reviews

# %%
y.loc[y.index > '2021-04'].nlargest(5)
# Out:
# 2021-11    13370
# 2021-05     6941
# 2021-09     6149
# 2022-12     6113
# 2022-01     5502
# Name: timestamp_created_utc_ym, dtype: int64

# %%
import matplotlib.ticker as ticker

time_voted=data[['timestamp_created_utc_ym', 'voted_up']].value_counts(sort=False).unstack()
ax = time_voted.plot(kind='bar',stacked=True)
time_voted.index=pd.to_datetime(time_voted.index)
ax.set_xlabel("Time") 
ax.set_ylabel("Counts") 
ax.legend(["Negative review","Positive review"])
# Working with tickers on x axis
ticklabels = ['']*len(time_voted.index) # Making most of the ticklabels empty 
ticklabels[::2] = [item.strftime('%b') for item in time_voted.index[::2]] # Every 2th ticklable shows the month
ticklabels[::12] = [item.strftime('%b\n%Y') for item in time_voted.index[::12]] # Every 12th ticklabel includes the year
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
plt.show()

# %%
time_voted2=time_voted.loc[time_voted.index > '2021-04']
ax = time_voted2.plot.bar(stacked=True) 
ax.set_xlabel("Time") 
ax.set_ylabel("Counts") 
ax.legend(["Negative review","Positive review"])
ticklabels = ['']*len(time_voted2.index)
ticklabels[::3] = [item.strftime('%b') for item in time_voted2.index[::3]]
ticklabels[::12] = [item.strftime('%b\n%Y') for item in time_voted2.index[::12]]
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
plt.show()

# %%
df=data[['timestamp_created_utc_ym','steam_purchase']].loc[data['voted_up']==False].value_counts(sort=False).unstack()
df.index=pd.to_datetime(df.index)
ax = df.plot.bar(stacked=True) 
ax.set_xlabel("Time") 
ax.set_ylabel("Counts") 
ax.legend(["Not purchased on Steam","Purchased on Steam"]) 
ax.set_title("Frequency of negative reviews by purchase place")
ticklabels = ['']*len(df.index)
ticklabels[::2] = [item.strftime('%b') for item in df.index[::2]]
ticklabels[::12] = [item.strftime('%b\n%Y') for item in df.index[::12]]
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
plt.show()

# %%
#sense check
df.head(5)
# Out:
# steam_purchase            False  True
# timestamp_created_utc_ym
# 2021-02                     399   1977
# 2021-03                     272   1362
# 2021-04                     115    482
# 2021-05                      61    342
# 2021-06                      45    284

# %%
df=data[['timestamp_created_utc_ym','steam_purchase']].loc[data['voted_up']==True].value_counts(sort=False).unstack()
df.index=pd.to_datetime(df.index)
ax = df.plot.bar(stacked=True) 
ax.set_xlabel("Time") 
ax.set_ylabel("Counts") 
ax.legend(["Not purchased on Steam","Purchased on Steam"])
ax.set_title("Frequency of positive reviews by purchase place")
ticklabels = ['']*len(df.index)
ticklabels[::2] = [item.strftime('%b') for item in df.index[::2]]
ticklabels[::12] = [item.strftime('%b\n%Y') for item in df.index[::12]]
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
plt.show()

# %%
#sense check
df.head(5)
# Out:
# steam_purchase            False  True
# timestamp_created_utc_ym
# 2021-02                    8321  69888
# 2021-03                    6187  42102
# 2021-04                    1868  12044
# 2021-05                     900   5638
# 2021-06                     621   3529

# %%
df=data[['timestamp_created_utc_ym','received_for_free']].loc[data['voted_up']==False].value_counts(sort=False).unstack()
df.index=pd.to_datetime(df.index)
ax = df.plot.bar(stacked=True) 
ax.set_xlabel("Time") 
ax.set_ylabel("Counts") 
ax.legend(["Paid","Received for free"])
ax.set_title("Frequency of negative reviews by purchase type")
ticklabels = ['']*len(df.index)
ticklabels[::2] = [item.strftime('%b') for item in df.index[::2]]
ticklabels[::12] = [item.strftime('%b\n%Y') for item in df.index[::12]]
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
plt.show()

# %%
#sense check
df.head(5)
# Out:
# received_for_free          False  True
# timestamp_created_utc_ym
# 2021-02                   2331.0   45.0
# 2021-03                   1599.0   35.0
# 2021-04                    580.0   17.0
# 2021-05                    392.0   11.0
# 2021-06                    324.0    5.0

# %%
df=data[['timestamp_created_utc_ym','received_for_free']].loc[data['voted_up']==True].value_counts(sort=False).unstack()
df.index=pd.to_datetime(df.index)
ax = df.plot.bar(stacked=True) 
ax.set_xlabel("Time") 
ax.set_ylabel("Counts") 
ax.legend(["Paid","Received for free"])
ax.set_title("Frequency of positive reviews by purchase type")
ticklabels = ['']*len(df.index)
ticklabels[::2] = [item.strftime('%b') for item in df.index[::2]]
ticklabels[::12] = [item.strftime('%b\n%Y') for item in df.index[::12]]
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
plt.show()

# %%
#sense check
df.head(5)
# Out:
# received_for_free         False  True
# timestamp_created_utc_ym
# 2021-02                   77140   1069
# 2021-03                   47446    843
# 2021-04                   13646    266
# 2021-05                    6410    128
# 2021-06                    4054     96

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243796 entries, 0 to 243795
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   recommendationid              243796 non-null  int64
#  1   review                        243796 non-null  object
#  2   timestamp_created             243796 non-null  int64
#  3   timestamp_updated             243796 non-null  int64
#  4   voted_up                      243796 non-null  bool
#  5   votes_up                      243796 non-null  int64
#  6   votes_funny                   243796 non-null  int64
#  7   weighted_vote_score           243796 non-null  float64
#  8   comment_count                 243796 non-null  int64
#  9   steam_purchase                243796 non-null  bool
#  10  received_for_free             243796 non-null  bool
#  11  steamid                       243796 non-null  int64
#  12  num_games_owned               243796 non-null  int64
#  13  num_reviews                   243796 non-null  int64
#  14  playtime_forever              243796 non-null  int64
#  15  playtime_last_two_weeks       243796 non-null  int64
#  16  playtime_at_review            243796 non-null  int64
#  17  last_played                   243796 non-null  int64
#  18  timestamp_created_utc         243796 non-null  object
#  19  timestamp_updated_utc         243796 non-null  object
#  20  last_played_utc               243796 non-null  object
#  21  playtime_forever_hour         243796 non-null  float64
#  22  playtime_last_two_weeks_hour  243796 non-null  float64
#  23  playtime_at_review_hour       243796 non-null  float64
#  24  timestamp_created_utc_ym      243796 non-null  object
#  25  timestamp_updated_utc_ym      243796 non-null  object
#  26  last_played_utc_ym            243796 non-null  object
# dtypes: bool(3), float64(4), int64(13), object(7)
# memory usage: 45.3+ MB

# %% [markdown]
# Features to explore:
# - votes_up
# - votes_funny
# - comment_count
# - num_games_owned
# - num_reviews
# - playtime_forever
# - playtime_at_review
# - last_played
